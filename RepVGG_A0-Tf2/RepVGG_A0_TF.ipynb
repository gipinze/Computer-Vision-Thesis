# %%
import tensorflow as tf
import os
from keras.layers import Conv2D, BatchNormalization, Dense, ReLU, GlobalAveragePooling2D
from keras import optimizers, Model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
from keras.utils import plot_model
import tensorflow_addons as tfa
from keras import Input
import time
import tensorflow as tf

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
physical_devices = tf.config.list_physical_devices('GPU')
try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    #Invalid device or can't modify virtual devices once installed
    print("Failed to limit the GPU Memory")

# %%
IMAGENET_TRAINSET_SIZE = 310284
IMG_SIZE = 224
batch_size = 32
epochs = 10
initial_lr = 1e-3
ADAM_LEARNING_RATE = 0.1
lr = 0.1
logdir = "logs_224x224"
csv_logger = CSVLogger('log.csv', separator=',', append=True)
adam = optimizers.Adam(learning_rate=ADAM_LEARNING_RATE)


train_dir = r'W:/10_percent/train/'
test_dir = r'W:/10_percent/test/'

# %%
# def read_image_label(file_path):
#     label = tf.strings.split(file_path, os.path.sep)[-2]
#     label = tf.strings.to_number(label, out_type=tf.int32)
#     image = tf.io.read_file(file_path)
#     image = tf.image.decode_jpeg(image, channels=3)
#     return image, label

def read_image_label(file_path):
    label = tf.strings.split(file_path, os.path.sep)[-2]
    label = tf.strings.to_number(label, out_type=tf.int32)
    label = tf.one_hot(label, 8631)
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)
    return image, label



def train_transform(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize_with_crop_or_pad(image, IMG_SIZE + 6, IMG_SIZE + 6)
    image = tf.image.random_crop(image, size=[IMG_SIZE, IMG_SIZE, 3])
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tfa.image.rotate(image, tf.random.uniform(shape=(), maxval=1))
    image = tf.image.random_brightness(image, 0.2)
    image = tf.math.divide(image, 255.0)
    image = (image - tf.constant([0.485, 0.456, 0.406])) / tf.constant(
        [0.229, 0.224, 0.225]
    )
    return image, label


def test_transform(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.math.divide(image, 255.0)
    image = (image - tf.constant([0.485, 0.456, 0.406])) / tf.constant(
        [0.229, 0.224, 0.225]
    )
    return image, label

# %%
train_ds = tf.data.Dataset.list_files(os.path.join(train_dir, "*", "*.jpg"))
train_ds = train_ds.map(read_image_label, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.shuffle(buffer_size=10000)
train_ds = train_ds.map(train_transform, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(batch_size)
train_ds = train_ds.prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.list_files(os.path.join(test_dir, "*", "*.jpg"))
test_ds = test_ds.map(read_image_label, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.map(test_transform, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(batch_size)
test_ds = test_ds.prefetch(AUTOTUNE)

# %%
for images, labels in train_ds.take(1):
    print(labels.shape)
# Out:
# (32, 8631)

# %%
def repvgg_block(inputs, out_channels, strides, stage, block):
    """
    RepVGG Block
    """
    if strides == 1:
        identity = inputs
    else:
        identity = Conv2D(out_channels, kernel_size=3, strides=strides, padding='same', use_bias=True, name=stage+"_idconv_"+block)(inputs)
        identity = BatchNormalization(name=stage+"_idbn_"+block)(identity)

    x = Conv2D(out_channels, kernel_size=3, strides=strides, padding='same', use_bias=True, name=stage+"_conv_"+block)(inputs)
    x = BatchNormalization(name=stage+"_bn_"+block)(x)
    x = ReLU()(x)

    x = Conv2D(out_channels, kernel_size=3, strides=1, padding='same', use_bias=True, name=stage+"_conv_"+block+"_1")(x)
    x = BatchNormalization(name=stage+"_bn_"+block+"_1")(x)
    x = ReLU()(x)

    x = Conv2D(out_channels, kernel_size=3, strides=1, padding='same', use_bias=True, name=stage+"_conv_"+block+"_2")(x)
    x = BatchNormalization(name=stage+"_bn_"+block+"_2")(x)

    x = x + identity
    x = ReLU()(x)

    return x

# %%
def create_RepVGG_A0(input_shape=(224, 224, 3), num_classes=8631):
    
    # Define input layer
    inputs = Input(shape=input_shape)

    x = repvgg_block(inputs, 64, 2, "stage1", "block1")
    x = repvgg_block(x, 64, 2, "stage1", "block2")
    x = repvgg_block(x, 64, 2, "stage1", "block3")
    x = repvgg_block(x, 128, 2, "stage2", "block1")
    x = repvgg_block(x, 128, 2, "stage2", "block2")
    x = repvgg_block(x, 128, 2, "stage2", "block3")
    x = repvgg_block(x, 256, 2, "stage3", "block1")
    x = repvgg_block(x, 256, 2, "stage3", "block2")
    x = repvgg_block(x, 256, 2, "stage3", "block3")
    x = repvgg_block(x, 512, 2, "stage4", "block1")
    x = repvgg_block(x, 512, 2, "stage4", "block2")
    x = repvgg_block(x, 512, 2, "stage4", "block3")

    # Classifier
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    # Create model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model = create_RepVGG_A0()
plot_model(model, to_file='model_architecture2.png', show_shapes=True)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stage1_conv_block1 (Conv2D)    (None, 112, 112, 64  1792        ['input_1[0][0]']
#                                 )
#
#  stage1_bn_block1 (BatchNormali  (None, 112, 112, 64  256        ['stage1_conv_block1[0][0]']
#  zation)                        )
#
#  re_lu (ReLU)                   (None, 112, 112, 64  0           ['stage1_bn_block1[0][0]']
#                                 )
#
#  stage1_conv_block1_1 (Conv2D)  (None, 112, 112, 64  36928       ['re_lu[0][0]']
#                                 )
#
#  stage1_bn_block1_1 (BatchNorma  (None, 112, 112, 64  256        ['stage1_conv_block1_1[0][0]']
#  lization)                      )
#
#  re_lu_1 (ReLU)                 (None, 112, 112, 64  0           ['stage1_bn_block1_1[0][0]']
#                                 )
#
#  stage1_conv_block1_2 (Conv2D)  (None, 112, 112, 64  36928       ['re_lu_1[0][0]']
#                                 )
#
#  stage1_idconv_block1 (Conv2D)  (None, 112, 112, 64  1792        ['input_1[0][0]']
#                                 )
#
#  stage1_bn_block1_2 (BatchNorma  (None, 112, 112, 64  256        ['stage1_conv_block1_2[0][0]']
#  lization)                      )
#
#  stage1_idbn_block1 (BatchNorma  (None, 112, 112, 64  256        ['stage1_idconv_block1[0][0]']
#  lization)                      )
#
#  tf.__operators__.add (TFOpLamb  (None, 112, 112, 64  0          ['stage1_bn_block1_2[0][0]',
#  da)                            )                                 'stage1_idbn_block1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 112, 112, 64  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  stage1_conv_block2 (Conv2D)    (None, 56, 56, 64)   36928       ['re_lu_2[0][0]']
#
#  stage1_bn_block2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_conv_block2[0][0]']
#  zation)
#
#  re_lu_3 (ReLU)                 (None, 56, 56, 64)   0           ['stage1_bn_block2[0][0]']
#
#  stage1_conv_block2_1 (Conv2D)  (None, 56, 56, 64)   36928       ['re_lu_3[0][0]']
#
#  stage1_bn_block2_1 (BatchNorma  (None, 56, 56, 64)  256         ['stage1_conv_block2_1[0][0]']
#  lization)
#
#  re_lu_4 (ReLU)                 (None, 56, 56, 64)   0           ['stage1_bn_block2_1[0][0]']
#
#  stage1_conv_block2_2 (Conv2D)  (None, 56, 56, 64)   36928       ['re_lu_4[0][0]']
#
#  stage1_idconv_block2 (Conv2D)  (None, 56, 56, 64)   36928       ['re_lu_2[0][0]']
#
#  stage1_bn_block2_2 (BatchNorma  (None, 56, 56, 64)  256         ['stage1_conv_block2_2[0][0]']
#  lization)
#
#  stage1_idbn_block2 (BatchNorma  (None, 56, 56, 64)  256         ['stage1_idconv_block2[0][0]']
#  lization)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 56, 56, 64)  0           ['stage1_bn_block2_2[0][0]',
#  mbda)                                                            'stage1_idbn_block2[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 64)   0           ['tf.__operators__.add_1[0][0]']
#
#  stage1_conv_block3 (Conv2D)    (None, 28, 28, 64)   36928       ['re_lu_5[0][0]']
#
#  stage1_bn_block3 (BatchNormali  (None, 28, 28, 64)  256         ['stage1_conv_block3[0][0]']
#  zation)
#
#  re_lu_6 (ReLU)                 (None, 28, 28, 64)   0           ['stage1_bn_block3[0][0]']
#
#  stage1_conv_block3_1 (Conv2D)  (None, 28, 28, 64)   36928       ['re_lu_6[0][0]']
#
#  stage1_bn_block3_1 (BatchNorma  (None, 28, 28, 64)  256         ['stage1_conv_block3_1[0][0]']
#  lization)
#
#  re_lu_7 (ReLU)                 (None, 28, 28, 64)   0           ['stage1_bn_block3_1[0][0]']
#
#  stage1_conv_block3_2 (Conv2D)  (None, 28, 28, 64)   36928       ['re_lu_7[0][0]']
#
#  stage1_idconv_block3 (Conv2D)  (None, 28, 28, 64)   36928       ['re_lu_5[0][0]']
#
#  stage1_bn_block3_2 (BatchNorma  (None, 28, 28, 64)  256         ['stage1_conv_block3_2[0][0]']
#  lization)
#
#  stage1_idbn_block3 (BatchNorma  (None, 28, 28, 64)  256         ['stage1_idconv_block3[0][0]']
#  lization)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 28, 28, 64)  0           ['stage1_bn_block3_2[0][0]',
#  mbda)                                                            'stage1_idbn_block3[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 28, 28, 64)   0           ['tf.__operators__.add_2[0][0]']
#
#  stage2_conv_block1 (Conv2D)    (None, 14, 14, 128)  73856       ['re_lu_8[0][0]']
#
#  stage2_bn_block1 (BatchNormali  (None, 14, 14, 128)  512        ['stage2_conv_block1[0][0]']
#  zation)
#
#  re_lu_9 (ReLU)                 (None, 14, 14, 128)  0           ['stage2_bn_block1[0][0]']
#
#  stage2_conv_block1_1 (Conv2D)  (None, 14, 14, 128)  147584      ['re_lu_9[0][0]']
#
#  stage2_bn_block1_1 (BatchNorma  (None, 14, 14, 128)  512        ['stage2_conv_block1_1[0][0]']
#  lization)
#
#  re_lu_10 (ReLU)                (None, 14, 14, 128)  0           ['stage2_bn_block1_1[0][0]']
#
#  stage2_conv_block1_2 (Conv2D)  (None, 14, 14, 128)  147584      ['re_lu_10[0][0]']
#
#  stage2_idconv_block1 (Conv2D)  (None, 14, 14, 128)  73856       ['re_lu_8[0][0]']
#
#  stage2_bn_block1_2 (BatchNorma  (None, 14, 14, 128)  512        ['stage2_conv_block1_2[0][0]']
#  lization)
#
#  stage2_idbn_block1 (BatchNorma  (None, 14, 14, 128)  512        ['stage2_idconv_block1[0][0]']
#  lization)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 14, 14, 128)  0          ['stage2_bn_block1_2[0][0]',
#  mbda)                                                            'stage2_idbn_block1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 14, 14, 128)  0           ['tf.__operators__.add_3[0][0]']
#
#  stage2_conv_block2 (Conv2D)    (None, 7, 7, 128)    147584      ['re_lu_11[0][0]']
#
#  stage2_bn_block2 (BatchNormali  (None, 7, 7, 128)   512         ['stage2_conv_block2[0][0]']
#  zation)
#
#  re_lu_12 (ReLU)                (None, 7, 7, 128)    0           ['stage2_bn_block2[0][0]']
#
#  stage2_conv_block2_1 (Conv2D)  (None, 7, 7, 128)    147584      ['re_lu_12[0][0]']
#
#  stage2_bn_block2_1 (BatchNorma  (None, 7, 7, 128)   512         ['stage2_conv_block2_1[0][0]']
#  lization)
#
#  re_lu_13 (ReLU)                (None, 7, 7, 128)    0           ['stage2_bn_block2_1[0][0]']
#
#  stage2_conv_block2_2 (Conv2D)  (None, 7, 7, 128)    147584      ['re_lu_13[0][0]']
#
#  stage2_idconv_block2 (Conv2D)  (None, 7, 7, 128)    147584      ['re_lu_11[0][0]']
#
#  stage2_bn_block2_2 (BatchNorma  (None, 7, 7, 128)   512         ['stage2_conv_block2_2[0][0]']
#  lization)
#
#  stage2_idbn_block2 (BatchNorma  (None, 7, 7, 128)   512         ['stage2_idconv_block2[0][0]']
#  lization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 7, 7, 128)   0           ['stage2_bn_block2_2[0][0]',
#  mbda)                                                            'stage2_idbn_block2[0][0]']
#
#  re_lu_14 (ReLU)                (None, 7, 7, 128)    0           ['tf.__operators__.add_4[0][0]']
#
#  stage2_conv_block3 (Conv2D)    (None, 4, 4, 128)    147584      ['re_lu_14[0][0]']
#
#  stage2_bn_block3 (BatchNormali  (None, 4, 4, 128)   512         ['stage2_conv_block3[0][0]']
#  zation)
#
#  re_lu_15 (ReLU)                (None, 4, 4, 128)    0           ['stage2_bn_block3[0][0]']
#
#  stage2_conv_block3_1 (Conv2D)  (None, 4, 4, 128)    147584      ['re_lu_15[0][0]']
#
#  stage2_bn_block3_1 (BatchNorma  (None, 4, 4, 128)   512         ['stage2_conv_block3_1[0][0]']
#  lization)
#
#  re_lu_16 (ReLU)                (None, 4, 4, 128)    0           ['stage2_bn_block3_1[0][0]']
#
#  stage2_conv_block3_2 (Conv2D)  (None, 4, 4, 128)    147584      ['re_lu_16[0][0]']
#
#  stage2_idconv_block3 (Conv2D)  (None, 4, 4, 128)    147584      ['re_lu_14[0][0]']
#
#  stage2_bn_block3_2 (BatchNorma  (None, 4, 4, 128)   512         ['stage2_conv_block3_2[0][0]']
#  lization)
#
#  stage2_idbn_block3 (BatchNorma  (None, 4, 4, 128)   512         ['stage2_idconv_block3[0][0]']
#  lization)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 4, 4, 128)   0           ['stage2_bn_block3_2[0][0]',
#  mbda)                                                            'stage2_idbn_block3[0][0]']
#
#  re_lu_17 (ReLU)                (None, 4, 4, 128)    0           ['tf.__operators__.add_5[0][0]']
#
#  stage3_conv_block1 (Conv2D)    (None, 2, 2, 256)    295168      ['re_lu_17[0][0]']
#
#  stage3_bn_block1 (BatchNormali  (None, 2, 2, 256)   1024        ['stage3_conv_block1[0][0]']
#  zation)
#
#  re_lu_18 (ReLU)                (None, 2, 2, 256)    0           ['stage3_bn_block1[0][0]']
#
#  stage3_conv_block1_1 (Conv2D)  (None, 2, 2, 256)    590080      ['re_lu_18[0][0]']
#
#  stage3_bn_block1_1 (BatchNorma  (None, 2, 2, 256)   1024        ['stage3_conv_block1_1[0][0]']
#  lization)
#
#  re_lu_19 (ReLU)                (None, 2, 2, 256)    0           ['stage3_bn_block1_1[0][0]']
#
#  stage3_conv_block1_2 (Conv2D)  (None, 2, 2, 256)    590080      ['re_lu_19[0][0]']
#
#  stage3_idconv_block1 (Conv2D)  (None, 2, 2, 256)    295168      ['re_lu_17[0][0]']
#
#  stage3_bn_block1_2 (BatchNorma  (None, 2, 2, 256)   1024        ['stage3_conv_block1_2[0][0]']
#  lization)
#
#  stage3_idbn_block1 (BatchNorma  (None, 2, 2, 256)   1024        ['stage3_idconv_block1[0][0]']
#  lization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 2, 2, 256)   0           ['stage3_bn_block1_2[0][0]',
#  mbda)                                                            'stage3_idbn_block1[0][0]']
#
#  re_lu_20 (ReLU)                (None, 2, 2, 256)    0           ['tf.__operators__.add_6[0][0]']
#
#  stage3_conv_block2 (Conv2D)    (None, 1, 1, 256)    590080      ['re_lu_20[0][0]']
#
#  stage3_bn_block2 (BatchNormali  (None, 1, 1, 256)   1024        ['stage3_conv_block2[0][0]']
#  zation)
#
#  re_lu_21 (ReLU)                (None, 1, 1, 256)    0           ['stage3_bn_block2[0][0]']
#
#  stage3_conv_block2_1 (Conv2D)  (None, 1, 1, 256)    590080      ['re_lu_21[0][0]']
#
#  stage3_bn_block2_1 (BatchNorma  (None, 1, 1, 256)   1024        ['stage3_conv_block2_1[0][0]']
#  lization)
#
#  re_lu_22 (ReLU)                (None, 1, 1, 256)    0           ['stage3_bn_block2_1[0][0]']
#
#  stage3_conv_block2_2 (Conv2D)  (None, 1, 1, 256)    590080      ['re_lu_22[0][0]']
#
#  stage3_idconv_block2 (Conv2D)  (None, 1, 1, 256)    590080      ['re_lu_20[0][0]']
#
#  stage3_bn_block2_2 (BatchNorma  (None, 1, 1, 256)   1024        ['stage3_conv_block2_2[0][0]']
#  lization)
#
#  stage3_idbn_block2 (BatchNorma  (None, 1, 1, 256)   1024        ['stage3_idconv_block2[0][0]']
#  lization)
#
#  tf.__operators__.add_7 (TFOpLa  (None, 1, 1, 256)   0           ['stage3_bn_block2_2[0][0]',
#  mbda)                                                            'stage3_idbn_block2[0][0]']
#
#  re_lu_23 (ReLU)                (None, 1, 1, 256)    0           ['tf.__operators__.add_7[0][0]']
#
#  stage3_conv_block3 (Conv2D)    (None, 1, 1, 256)    590080      ['re_lu_23[0][0]']
#
#  stage3_bn_block3 (BatchNormali  (None, 1, 1, 256)   1024        ['stage3_conv_block3[0][0]']
#  zation)
#
#  re_lu_24 (ReLU)                (None, 1, 1, 256)    0           ['stage3_bn_block3[0][0]']
#
#  stage3_conv_block3_1 (Conv2D)  (None, 1, 1, 256)    590080      ['re_lu_24[0][0]']
#
#  stage3_bn_block3_1 (BatchNorma  (None, 1, 1, 256)   1024        ['stage3_conv_block3_1[0][0]']
#  lization)
#
#  re_lu_25 (ReLU)                (None, 1, 1, 256)    0           ['stage3_bn_block3_1[0][0]']
#
#  stage3_conv_block3_2 (Conv2D)  (None, 1, 1, 256)    590080      ['re_lu_25[0][0]']
#
#  stage3_idconv_block3 (Conv2D)  (None, 1, 1, 256)    590080      ['re_lu_23[0][0]']
#
#  stage3_bn_block3_2 (BatchNorma  (None, 1, 1, 256)   1024        ['stage3_conv_block3_2[0][0]']
#  lization)
#
#  stage3_idbn_block3 (BatchNorma  (None, 1, 1, 256)   1024        ['stage3_idconv_block3[0][0]']
#  lization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 1, 1, 256)   0           ['stage3_bn_block3_2[0][0]',
#  mbda)                                                            'stage3_idbn_block3[0][0]']
#
#  re_lu_26 (ReLU)                (None, 1, 1, 256)    0           ['tf.__operators__.add_8[0][0]']
#
#  stage4_conv_block1 (Conv2D)    (None, 1, 1, 512)    1180160     ['re_lu_26[0][0]']
#
#  stage4_bn_block1 (BatchNormali  (None, 1, 1, 512)   2048        ['stage4_conv_block1[0][0]']
#  zation)
#
#  re_lu_27 (ReLU)                (None, 1, 1, 512)    0           ['stage4_bn_block1[0][0]']
#
#  stage4_conv_block1_1 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_27[0][0]']
#
#  stage4_bn_block1_1 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_conv_block1_1[0][0]']
#  lization)
#
#  re_lu_28 (ReLU)                (None, 1, 1, 512)    0           ['stage4_bn_block1_1[0][0]']
#
#  stage4_conv_block1_2 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_28[0][0]']
#
#  stage4_idconv_block1 (Conv2D)  (None, 1, 1, 512)    1180160     ['re_lu_26[0][0]']
#
#  stage4_bn_block1_2 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_conv_block1_2[0][0]']
#  lization)
#
#  stage4_idbn_block1 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_idconv_block1[0][0]']
#  lization)
#
#  tf.__operators__.add_9 (TFOpLa  (None, 1, 1, 512)   0           ['stage4_bn_block1_2[0][0]',
#  mbda)                                                            'stage4_idbn_block1[0][0]']
#
#  re_lu_29 (ReLU)                (None, 1, 1, 512)    0           ['tf.__operators__.add_9[0][0]']
#
#  stage4_conv_block2 (Conv2D)    (None, 1, 1, 512)    2359808     ['re_lu_29[0][0]']
#
#  stage4_bn_block2 (BatchNormali  (None, 1, 1, 512)   2048        ['stage4_conv_block2[0][0]']
#  zation)
#
#  re_lu_30 (ReLU)                (None, 1, 1, 512)    0           ['stage4_bn_block2[0][0]']
#
#  stage4_conv_block2_1 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_30[0][0]']
#
#  stage4_bn_block2_1 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_conv_block2_1[0][0]']
#  lization)
#
#  re_lu_31 (ReLU)                (None, 1, 1, 512)    0           ['stage4_bn_block2_1[0][0]']
#
#  stage4_conv_block2_2 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_31[0][0]']
#
#  stage4_idconv_block2 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_29[0][0]']
#
#  stage4_bn_block2_2 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_conv_block2_2[0][0]']
#  lization)
#
#  stage4_idbn_block2 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_idconv_block2[0][0]']
#  lization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 1, 1, 512)   0           ['stage4_bn_block2_2[0][0]',
#  ambda)                                                           'stage4_idbn_block2[0][0]']
#
#  re_lu_32 (ReLU)                (None, 1, 1, 512)    0           ['tf.__operators__.add_10[0][0]']
#
#  stage4_conv_block3 (Conv2D)    (None, 1, 1, 512)    2359808     ['re_lu_32[0][0]']
#
#  stage4_bn_block3 (BatchNormali  (None, 1, 1, 512)   2048        ['stage4_conv_block3[0][0]']
#  zation)
#
#  re_lu_33 (ReLU)                (None, 1, 1, 512)    0           ['stage4_bn_block3[0][0]']
#
#  stage4_conv_block3_1 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_33[0][0]']
#
#  stage4_bn_block3_1 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_conv_block3_1[0][0]']
#  lization)
#
#  re_lu_34 (ReLU)                (None, 1, 1, 512)    0           ['stage4_bn_block3_1[0][0]']
#
#  stage4_conv_block3_2 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_34[0][0]']
#
#  stage4_idconv_block3 (Conv2D)  (None, 1, 1, 512)    2359808     ['re_lu_32[0][0]']
#
#  stage4_bn_block3_2 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_conv_block3_2[0][0]']
#  lization)
#
#  stage4_idbn_block3 (BatchNorma  (None, 1, 1, 512)   2048        ['stage4_idconv_block3[0][0]']
#  lization)
#
#  tf.__operators__.add_11 (TFOpL  (None, 1, 1, 512)   0           ['stage4_bn_block3_2[0][0]',
#  ambda)                                                           'stage4_idbn_block3[0][0]']
#
#  re_lu_35 (ReLU)                (None, 1, 1, 512)    0           ['tf.__operators__.add_11[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['re_lu_35[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 8631)         4427703     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 38,919,735
# Trainable params: 38,896,695
# Non-trainable params: 23,040
# __________________________________________________________________________________________________

# %% [markdown]
# ## Checkpoint creation (in order to train the model in different days)

# %%
checkpoint_dir = './model_checkpoint'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# %%
# Create a ModelCheckpoint callback to save the model weights
# every 10 epochs and only save the best weights based on 
# validation loss
checkpoint_filepath = './model_checkpoint'

# Define callbacks to save checkpoints every 10 epochs
checkpoint_filepath = checkpoint_filepath
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    save_freq=10*len(train_ds),  # Save every 10 epochs
)

# %%
# Set learning rate
initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %%
# Compile model
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['accuracy']
)

# %%
history = model.fit(train_ds,
                    validation_data=test_ds,
                    epochs=3,
                    callbacks=[checkpoint_callback, csv_logger])
# Out:
# Epoch 1/3
# 2859/9697 [=======>......................] - ETA: 15:10 - loss: 8.4671 - accuracy: 1.8582e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 history = model.fit(train_ds,
#       2                     validation_data=test_ds,
#       3                     epochs=3,
#       4                     callbacks=[checkpoint_callback, csv_logger])
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save_weights('3e_normDS_weights.h5')
model.save('final_model.h5')

# %%
# check time for evaluation
start_ts_eval = time.time()
model.evaluate(test_ds)
print(f"Evaluation of trained model takes: {time.time() - start_ts_eval:.4f}s")

# %%
latest_checkpoint = tf.train.latest_checkpoint(checkpoint_dir)
model.load_weights(latest_checkpoint)

# %%
from keras.models import load_model

# load the pre-trained model
model = load_model('final_model.h5')

# %%
history = model.fit(train_ds,
                    validation_data=test_ds,
                    epochs=10,
                    callbacks=[tf.keras.callbacks.TensorBoard(log_dir=logdir, profile_batch=0),])

# %%
model.save_weights('30e+10_normDS_weights.h5')
model.save('final_model.h5')
