# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import pandas as pd

# %%
img1_path = "dataset_test/img1.jpg"
img2_path = "dataset_test/img3.jpg"

# %%
img1 = DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
model_name = 'ArcFace'

# %%
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = model_name)
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step

# %%
resp # ArcFace Jolie and Aniston
# Out:
# {'verified': False,
#  'distance': 0.9573503145055511,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
resp # Arc Face
# Out:
# {'verified': True,
#  'distance': 0.49400093363448505,
#  'threshold': 0.68,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
resp # VGG-Face
# Out:
# {'verified': True,
#  'distance': 0.2554689556937475,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
resp # Facenet
# Out:
# {'verified': True,
#  'distance': 0.24255809935152228,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
# How to find a similar photo (based on the face) by giving the example and the place where to search for it (folder)

df = DeepFace.find(img_path= 'example2.jpg', db_path='dataset_test/')
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# Representations stored in  dataset_test/ / representations_vgg_face.pkl  file. Please delete this file when you add new identities in your database.
# 1/1 [==============================] - 0s 17ms/step
# find function lasts  2.6997768878936768  seconds

# %%
df.head() # This shows the closest picture to the input
# Out:
#                   identity  VGG-Face_cosine
# 0   dataset_test//img2.jpg         0.283200
# 1  dataset_test//img11.jpg         0.297691
# 2  dataset_test//img10.jpg         0.351474

# %%
# Facial attribute analysis (Emotion, age, gender and race)

obj = DeepFace.analyze(img_path = img1_path)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.92it/s]

# %%
plt.imshow(img1)

# %%
obj
# Out:
# {'emotion': {'angry': 8.591450197743115e-22,
#   'disgust': 0.0,
#   'fear': 1.7969565850059758e-27,
#   'happy': 100.0,
#   'sad': 3.7551098215414985e-18,
#   'surprise': 7.565321979985384e-09,
#   'neutral': 2.3129309578706625e-07},
#  'dominant_emotion': 'happy',
#  'region': {'x': 345, 'y': 211, 'w': 769, 'h': 769},
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 9.936189651489258,
#   'indian': 13.224846124649048,
#   'black': 3.635922074317932,
#   'white': 23.47080558538437,
#   'middle eastern': 20.3949972987175,
#   'latino hispanic': 29.337242245674133},
#  'dominant_race': 'latino hispanic'}
