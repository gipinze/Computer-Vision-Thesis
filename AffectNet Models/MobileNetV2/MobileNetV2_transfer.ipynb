# %% [markdown]
# Tell the model to ONLY use GPU

# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %% [markdown]
# Import libraries

# %%
import tensorflow as tf
from keras import Model, regularizers
from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from keras.layers import Conv2D, MaxPooling2D, Dense, Input, Flatten, Dropout, UpSampling2D, GlobalAveragePooling2D, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, GlobalAveragePooling2D,Dropout, DepthwiseConv2D
import itertools
from keras.utils import plot_model
from keras.utils.image_utils import img_to_array, array_to_img, img_to_array, load_img
from keras.optimizers import Adam, SGD
from keras import models, Sequential
import keras.backend as K
from keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.models import load_model
import matplotlib.pyplot as plt
import random
import cv2
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import Image, HTML
import seaborn as sn
from collections import Counter

# %% [markdown]
# Limit the GPU growth to only what's needed

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    #Invalid device or can't modify virtual devices once installed
    print("Failed to limit the GPU Memory")

# %% [markdown]
# Gather Data

# %%
IMG_HEIGHT=224 
IMG_WIDTH = 224
IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)

IMAGE_SHAPE = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 1))

batch_size=32

PATIENCE =10

epochs = 50

csv_logger = CSVLogger('log.csv', separator=',', append=True)

ADAM_LEARNING_RATE = 0.0001

classes=['Angry','Contemp', 'Disgust','Fear','Happy','Neutral','Sad','Surprise']

train_data_dir = r'../../DATASETS/AffectNet/train/'
validation_data_dir = r'../../DATASETS/AffectNet/test/'

# %%
# Data augmentation

train_generator = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   fill_mode='nearest',
                                   horizontal_flip=True)

validation_generator  = ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_generator.flow_from_directory(directory = train_data_dir,
                                                   target_size = IMG_SIZE,
                                                   class_mode = 'categorical',
                                                   color_mode='grayscale',
                                                   batch_size = batch_size,
                                                   shuffle=True)

test_dataset = validation_generator.flow_from_directory(directory = validation_data_dir,
                                                  target_size = IMG_SIZE,
                                                  class_mode = 'categorical',
                                                  color_mode='grayscale',
                                                  shuffle =True,
                                                  batch_size = batch_size)
# Out:
# Found 24799 images belonging to 8 classes.
# Found 6192 images belonging to 8 classes.

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_data_dir, 'train')
test_count = count_exp(validation_data_dir, 'test')

HTML(train_count.append(test_count).to_html(escape=False))

# HTML(train_count.append(test_count).to_html(escape=False))
# Out:
# C:\Users\darks\AppData\Local\Temp\ipykernel_23892\2138799908.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   HTML(train_count.append(test_count).to_html(escape=False))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>anger</th>
#       <th>contempt</th>
#       <th>disgust</th>
#       <th>fear</th>
#       <th>happy</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>surprise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>2910</td>
#       <td>2543</td>
#       <td>2128</td>
#       <td>2897</td>
#       <td>4036</td>
#       <td>4105</td>
#       <td>2744</td>
#       <td>3436</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>721</td>
#       <td>635</td>
#       <td>532</td>
#       <td>724</td>
#       <td>1009</td>
#       <td>1026</td>
#       <td>686</td>
#       <td>859</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'anger': 0,
#  'contempt': 1,
#  'disgust': 2,
#  'fear': 3,
#  'happy': 4,
#  'neutral': 5,
#  'sad': 6,
#  'surprise': 7}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (32, 224, 224, 1)

# %%
# # lot distribution of train/test dataste per class

x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_data_dir):
    img = load_img((train_data_dir + expression +'/'+ os.listdir(train_data_dir + expression)[1]))
    plt.subplot(1,8,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# Build the Model
#
# Load pre-trained model and add extra dense layer for classification

# %%
base_model = MobileNetV2(include_top=False, weights='imagenet')

base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_2[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# Freezing Layers all layers

for layer in base_model.layers:
    layer.trainable=False

# %%
print("Model trainable",len(base_model.layers))
# Out:
# Model trainable 154

# %%
# Model trainable

print("Model trainable",len(base_model.trainable_variables))
# Out:
# Model trainable 0

# %%
# Build transfer learning Model

input = Input(shape=(IMG_HEIGHT, IMG_WIDTH, 1))

conv = Conv2D(3, kernel_size=(3, 3), padding='same')(input)

model = base_model(conv)

model = GlobalAveragePooling2D()(model)

model = Flatten()(model)
model = Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001))(model)
model = BatchNormalization()(model)
model = Dropout(0.3)(model)

model = Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001))(model)
model = BatchNormalization()(model)
model = Dropout(0.3)(model)

pred = Dense(8, activation="softmax")(model)

model = Model(inputs = input, outputs = pred)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       30
#
#  mobilenetv2_1.00_224 (Funct  (None, None, None, 1280)  2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 256)               327936
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 2,621,414
# Trainable params: 362,662
# Non-trainable params: 2,258,752
# _________________________________________________________________

# %% [markdown]
# Compile and Fit Model

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = Adam(learning_rate= ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model.h5')
es = EarlyStopping(verbose=1, patience=20)

# %%
history = model.fit(train_dataset, validation_data = test_dataset, epochs = epochs, callbacks=[lrd,mcp,es,csv_logger], class_weight = class_weights)
# Out:
# Epoch 1/50
# 775/775 [==============================] - 302s 370ms/step - loss: 3.6439 - accuracy: 0.8546 - precision: 0.3231 - recall: 0.1493 - auc: 0.6781 - f1_score: 0.2024 - val_loss: 2.3273 - val_accuracy: 0.8727 - val_precision: 0.4795 - val_recall: 0.2174 - val_auc: 0.7834 - val_f1_score: 0.2978 - lr: 1.0000e-04
# Epoch 2/50
# 775/775 [==============================] - 273s 352ms/step - loss: 3.1322 - accuracy: 0.8675 - precision: 0.4366 - recall: 0.2073 - auc: 0.7602 - f1_score: 0.2796 - val_loss: 2.1581 - val_accuracy: 0.8795 - val_precision: 0.5397 - val_recall: 0.2424 - val_auc: 0.8156 - val_f1_score: 0.3313 - lr: 1.0000e-04
# Epoch 3/50
# 775/775 [==============================] - 272s 350ms/step - loss: 2.9237 - accuracy: 0.8741 - precision: 0.4923 - recall: 0.2239 - auc: 0.7876 - f1_score: 0.3061 - val_loss: 2.0645 - val_accuracy: 0.8834 - val_precision: 0.5729 - val_recall: 0.2634 - val_auc: 0.8320 - val_f1_score: 0.3584 - lr: 1.0000e-04
# Epoch 4/50
# 775/775 [==============================] - 276s 356ms/step - loss: 2.8005 - accuracy: 0.8772 - precision: 0.5197 - recall: 0.2334 - auc: 0.8039 - f1_score: 0.3204 - val_loss: 2.0383 - val_accuracy: 0.8850 - val_precision: 0.5847 - val_recall: 0.2765 - val_auc: 0.8350 - val_f1_score: 0.3722 - lr: 1.0000e-04
# Epoch 5/50
# 775/775 [==============================] - 275s 355ms/step - loss: 2.6874 - accuracy: 0.8813 - precision: 0.5584 - recall: 0.2415 - auc: 0.8179 - f1_score: 0.3353 - val_loss: 1.9489 - val_accuracy: 0.8873 - val_precision: 0.6072 - val_recall: 0.2791 - val_auc: 0.8479 - val_f1_score: 0.3796 - lr: 1.0000e-04
# Epoch 6/50
# 775/775 [==============================] - 276s 355ms/step - loss: 2.6114 - accuracy: 0.8829 - precision: 0.5748 - recall: 0.2422 - auc: 0.8251 - f1_score: 0.3387 - val_loss: 1.8853 - val_accuracy: 0.8909 - val_precision: 0.6430 - val_recall: 0.2857 - val_auc: 0.8550 - val_f1_score: 0.3928 - lr: 1.0000e-04
# Epoch 7/50
# 775/775 [==============================] - 273s 353ms/step - loss: 2.5480 - accuracy: 0.8843 - precision: 0.5894 - recall: 0.2442 - auc: 0.8317 - f1_score: 0.3432 - val_loss: 1.8559 - val_accuracy: 0.8902 - val_precision: 0.6398 - val_recall: 0.2786 - val_auc: 0.8573 - val_f1_score: 0.3848 - lr: 1.0000e-04
# Epoch 8/50
# 775/775 [==============================] - 274s 354ms/step - loss: 2.4758 - accuracy: 0.8872 - precision: 0.6195 - recall: 0.2531 - auc: 0.8399 - f1_score: 0.3570 - val_loss: 1.8250 - val_accuracy: 0.8924 - val_precision: 0.6568 - val_recall: 0.2915 - val_auc: 0.8589 - val_f1_score: 0.4013 - lr: 1.0000e-04
# Epoch 9/50
# 775/775 [==============================] - 269s 347ms/step - loss: 2.4303 - accuracy: 0.8877 - precision: 0.6214 - recall: 0.2595 - auc: 0.8442 - f1_score: 0.3639 - val_loss: 1.8150 - val_accuracy: 0.8906 - val_precision: 0.6367 - val_recall: 0.2912 - val_auc: 0.8577 - val_f1_score: 0.3957 - lr: 1.0000e-04
# Epoch 10/50
# 775/775 [==============================] - 268s 345ms/step - loss: 2.3713 - accuracy: 0.8894 - precision: 0.6388 - recall: 0.2648 - auc: 0.8495 - f1_score: 0.3720 - val_loss: 1.7713 - val_accuracy: 0.8914 - val_precision: 0.6482 - val_recall: 0.2860 - val_auc: 0.8623 - val_f1_score: 0.3942 - lr: 1.0000e-04
# Epoch 11/50
# 775/775 [==============================] - 276s 356ms/step - loss: 2.3339 - accuracy: 0.8902 - precision: 0.6464 - recall: 0.2685 - auc: 0.8535 - f1_score: 0.3773 - val_loss: 1.7624 - val_accuracy: 0.8922 - val_precision: 0.6517 - val_recall: 0.2959 - val_auc: 0.8609 - val_f1_score: 0.4032 - lr: 1.0000e-04
# Epoch 12/50
# 775/775 [==============================] - 276s 355ms/step - loss: 2.2958 - accuracy: 0.8899 - precision: 0.6459 - recall: 0.2645 - auc: 0.8561 - f1_score: 0.3730 - val_loss: 1.7079 - val_accuracy: 0.8930 - val_precision: 0.6691 - val_recall: 0.2844 - val_auc: 0.8677 - val_f1_score: 0.3954 - lr: 1.0000e-04
# Epoch 13/50
# 775/775 [==============================] - 272s 351ms/step - loss: 2.2599 - accuracy: 0.8912 - precision: 0.6586 - recall: 0.2688 - auc: 0.8594 - f1_score: 0.3797 - val_loss: 1.7302 - val_accuracy: 0.8924 - val_precision: 0.6477 - val_recall: 0.3052 - val_auc: 0.8618 - val_f1_score: 0.4123 - lr: 1.0000e-04
# Epoch 14/50
# 775/775 [==============================] - 274s 353ms/step - loss: 2.2293 - accuracy: 0.8920 - precision: 0.6637 - recall: 0.2765 - auc: 0.8619 - f1_score: 0.3883 - val_loss: 1.6752 - val_accuracy: 0.8941 - val_precision: 0.6740 - val_recall: 0.2959 - val_auc: 0.8680 - val_f1_score: 0.4083 - lr: 1.0000e-04
# Epoch 15/50
# 775/775 [==============================] - 271s 349ms/step - loss: 2.2023 - accuracy: 0.8925 - precision: 0.6676 - recall: 0.2783 - auc: 0.8640 - f1_score: 0.3908 - val_loss: 1.6631 - val_accuracy: 0.8934 - val_precision: 0.6639 - val_recall: 0.2983 - val_auc: 0.8682 - val_f1_score: 0.4081 - lr: 1.0000e-04
# Epoch 16/50
# 775/775 [==============================] - 268s 345ms/step - loss: 2.1617 - accuracy: 0.8934 - precision: 0.6754 - recall: 0.2833 - auc: 0.8686 - f1_score: 0.3966 - val_loss: 1.6257 - val_accuracy: 0.8966 - val_precision: 0.6831 - val_recall: 0.3224 - val_auc: 0.8733 - val_f1_score: 0.4341 - lr: 1.0000e-04
# Epoch 17/50
# 775/775 [==============================] - 268s 345ms/step - loss: 2.1430 - accuracy: 0.8944 - precision: 0.6794 - recall: 0.2941 - auc: 0.8699 - f1_score: 0.4083 - val_loss: 1.6063 - val_accuracy: 0.8958 - val_precision: 0.6792 - val_recall: 0.3146 - val_auc: 0.8747 - val_f1_score: 0.4261 - lr: 1.0000e-04
# Epoch 18/50
# 775/775 [==============================] - 267s 344ms/step - loss: 2.1244 - accuracy: 0.8942 - precision: 0.6795 - recall: 0.2911 - auc: 0.8704 - f1_score: 0.4056 - val_loss: 1.6079 - val_accuracy: 0.8941 - val_precision: 0.6656 - val_recall: 0.3064 - val_auc: 0.8725 - val_f1_score: 0.4171 - lr: 1.0000e-04
# Epoch 19/50
# 775/775 [==============================] - 268s 346ms/step - loss: 2.1069 - accuracy: 0.8950 - precision: 0.6861 - recall: 0.2956 - auc: 0.8719 - f1_score: 0.4113 - val_loss: 1.5687 - val_accuracy: 0.8965 - val_precision: 0.6851 - val_recall: 0.3190 - val_auc: 0.8781 - val_f1_score: 0.4327 - lr: 1.0000e-04
# Epoch 20/50
# 775/775 [==============================] - 267s 344ms/step - loss: 2.0966 - accuracy: 0.8946 - precision: 0.6811 - recall: 0.2954 - auc: 0.8723 - f1_score: 0.4099 - val_loss: 1.5722 - val_accuracy: 0.8958 - val_precision: 0.6797 - val_recall: 0.3140 - val_auc: 0.8756 - val_f1_score: 0.4267 - lr: 1.0000e-04
# Epoch 21/50
# 775/775 [==============================] - 267s 345ms/step - loss: 2.0707 - accuracy: 0.8952 - precision: 0.6874 - recall: 0.2967 - auc: 0.8746 - f1_score: 0.4122 - val_loss: 1.5558 - val_accuracy: 0.8966 - val_precision: 0.6837 - val_recall: 0.3215 - val_auc: 0.8771 - val_f1_score: 0.4339 - lr: 1.0000e-04
# Epoch 22/50
# 775/775 [==============================] - 268s 346ms/step - loss: 2.0487 - accuracy: 0.8960 - precision: 0.6928 - recall: 0.3026 - auc: 0.8767 - f1_score: 0.4187 - val_loss: 1.5634 - val_accuracy: 0.8975 - val_precision: 0.6896 - val_recall: 0.3272 - val_auc: 0.8744 - val_f1_score: 0.4408 - lr: 1.0000e-04
# Epoch 23/50
# 775/775 [==============================] - 267s 345ms/step - loss: 2.0385 - accuracy: 0.8965 - precision: 0.6953 - recall: 0.3066 - auc: 0.8774 - f1_score: 0.4235 - val_loss: 1.5421 - val_accuracy: 0.8958 - val_precision: 0.6762 - val_recall: 0.3191 - val_auc: 0.8773 - val_f1_score: 0.4297 - lr: 1.0000e-04
# Epoch 24/50
# 775/775 [==============================] - 268s 346ms/step - loss: 2.0298 - accuracy: 0.8970 - precision: 0.6979 - recall: 0.3098 - auc: 0.8771 - f1_score: 0.4270 - val_loss: 1.5194 - val_accuracy: 0.8971 - val_precision: 0.6903 - val_recall: 0.3211 - val_auc: 0.8797 - val_f1_score: 0.4347 - lr: 1.0000e-04
# Epoch 25/50
# 775/775 [==============================] - 267s 344ms/step - loss: 2.0062 - accuracy: 0.8971 - precision: 0.6996 - recall: 0.3105 - auc: 0.8797 - f1_score: 0.4278 - val_loss: 1.5050 - val_accuracy: 0.8975 - val_precision: 0.6969 - val_recall: 0.3193 - val_auc: 0.8810 - val_f1_score: 0.4328 - lr: 1.0000e-04
# Epoch 26/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.9855 - accuracy: 0.8978 - precision: 0.7019 - recall: 0.3174 - auc: 0.8818 - f1_score: 0.4345 - val_loss: 1.4976 - val_accuracy: 0.8974 - val_precision: 0.6883 - val_recall: 0.3274 - val_auc: 0.8812 - val_f1_score: 0.4403 - lr: 1.0000e-04
# Epoch 27/50
# 775/775 [==============================] - 266s 344ms/step - loss: 1.9825 - accuracy: 0.8979 - precision: 0.7027 - recall: 0.3182 - auc: 0.8810 - f1_score: 0.4357 - val_loss: 1.4877 - val_accuracy: 0.8973 - val_precision: 0.6904 - val_recall: 0.3238 - val_auc: 0.8822 - val_f1_score: 0.4372 - lr: 1.0000e-04
# Epoch 28/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.9697 - accuracy: 0.8975 - precision: 0.6985 - recall: 0.3173 - auc: 0.8820 - f1_score: 0.4341 - val_loss: 1.4914 - val_accuracy: 0.8962 - val_precision: 0.6716 - val_recall: 0.3325 - val_auc: 0.8806 - val_f1_score: 0.4421 - lr: 1.0000e-04
# Epoch 29/50
# 775/775 [==============================] - 268s 346ms/step - loss: 1.9605 - accuracy: 0.8977 - precision: 0.7002 - recall: 0.3174 - auc: 0.8830 - f1_score: 0.4343 - val_loss: 1.5090 - val_accuracy: 0.8961 - val_precision: 0.6729 - val_recall: 0.3278 - val_auc: 0.8759 - val_f1_score: 0.4371 - lr: 1.0000e-04
# Epoch 30/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.9573 - accuracy: 0.8982 - precision: 0.7015 - recall: 0.3225 - auc: 0.8828 - f1_score: 0.4394 - val_loss: 1.4654 - val_accuracy: 0.8973 - val_precision: 0.6839 - val_recall: 0.3319 - val_auc: 0.8836 - val_f1_score: 0.4436 - lr: 1.0000e-04
# Epoch 31/50
# 775/775 [==============================] - 266s 343ms/step - loss: 1.9398 - accuracy: 0.8981 - precision: 0.7026 - recall: 0.3198 - auc: 0.8844 - f1_score: 0.4370 - val_loss: 1.4597 - val_accuracy: 0.8986 - val_precision: 0.6911 - val_recall: 0.3411 - val_auc: 0.8833 - val_f1_score: 0.4539 - lr: 1.0000e-04
# Epoch 32/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.9368 - accuracy: 0.8982 - precision: 0.7016 - recall: 0.3230 - auc: 0.8843 - f1_score: 0.4400 - val_loss: 1.4577 - val_accuracy: 0.8985 - val_precision: 0.6963 - val_recall: 0.3332 - val_auc: 0.8830 - val_f1_score: 0.4475 - lr: 1.0000e-04
# Epoch 33/50
# 775/775 [==============================] - 266s 343ms/step - loss: 1.9153 - accuracy: 0.8987 - precision: 0.7030 - recall: 0.3276 - auc: 0.8865 - f1_score: 0.4444 - val_loss: 1.4662 - val_accuracy: 0.8968 - val_precision: 0.6732 - val_recall: 0.3383 - val_auc: 0.8809 - val_f1_score: 0.4466 - lr: 1.0000e-04
# Epoch 34/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.9076 - accuracy: 0.8998 - precision: 0.7117 - recall: 0.3331 - auc: 0.8872 - f1_score: 0.4519 - val_loss: 1.4515 - val_accuracy: 0.8970 - val_precision: 0.6827 - val_recall: 0.3291 - val_auc: 0.8831 - val_f1_score: 0.4407 - lr: 1.0000e-04
# Epoch 35/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.8946 - accuracy: 0.8999 - precision: 0.7106 - recall: 0.3366 - auc: 0.8884 - f1_score: 0.4545 - val_loss: 1.4638 - val_accuracy: 0.8962 - val_precision: 0.6635 - val_recall: 0.3448 - val_auc: 0.8803 - val_f1_score: 0.4512 - lr: 1.0000e-04
# Epoch 36/50
# 775/775 [==============================] - 266s 343ms/step - loss: 1.8968 - accuracy: 0.8992 - precision: 0.7049 - recall: 0.3326 - auc: 0.8877 - f1_score: 0.4496 - val_loss: 1.4405 - val_accuracy: 0.8970 - val_precision: 0.6825 - val_recall: 0.3288 - val_auc: 0.8837 - val_f1_score: 0.4401 - lr: 1.0000e-04
# Epoch 37/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.8852 - accuracy: 0.9000 - precision: 0.7111 - recall: 0.3374 - auc: 0.8887 - f1_score: 0.4552 - val_loss: 1.4317 - val_accuracy: 0.8992 - val_precision: 0.6895 - val_recall: 0.3526 - val_auc: 0.8847 - val_f1_score: 0.4640 - lr: 1.0000e-04
# Epoch 38/50
# 775/775 [==============================] - 269s 347ms/step - loss: 1.8904 - accuracy: 0.8996 - precision: 0.7043 - recall: 0.3391 - auc: 0.8878 - f1_score: 0.4556 - val_loss: 1.4270 - val_accuracy: 0.8992 - val_precision: 0.6956 - val_recall: 0.3440 - val_auc: 0.8850 - val_f1_score: 0.4570 - lr: 1.0000e-04
# Epoch 39/50
# 775/775 [==============================] - 274s 353ms/step - loss: 1.8796 - accuracy: 0.8998 - precision: 0.7085 - recall: 0.3368 - auc: 0.8886 - f1_score: 0.4541 - val_loss: 1.4372 - val_accuracy: 0.8980 - val_precision: 0.6784 - val_recall: 0.3495 - val_auc: 0.8828 - val_f1_score: 0.4589 - lr: 1.0000e-04
# Epoch 40/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.8744 - accuracy: 0.8988 - precision: 0.6995 - recall: 0.3332 - auc: 0.8889 - f1_score: 0.4491 - val_loss: 1.4186 - val_accuracy: 0.8984 - val_precision: 0.6909 - val_recall: 0.3387 - val_auc: 0.8855 - val_f1_score: 0.4515 - lr: 1.0000e-04
# Epoch 41/50
# 775/775 [==============================] - 269s 346ms/step - loss: 1.8520 - accuracy: 0.9004 - precision: 0.7091 - recall: 0.3441 - auc: 0.8920 - f1_score: 0.4610 - val_loss: 1.4149 - val_accuracy: 0.8990 - val_precision: 0.7006 - val_recall: 0.3348 - val_auc: 0.8851 - val_f1_score: 0.4498 - lr: 1.0000e-04
# Epoch 42/50
# 775/775 [==============================] - 270s 348ms/step - loss: 1.8561 - accuracy: 0.9009 - precision: 0.7136 - recall: 0.3464 - auc: 0.8912 - f1_score: 0.4637 - val_loss: 1.4035 - val_accuracy: 0.8998 - val_precision: 0.7130 - val_recall: 0.3322 - val_auc: 0.8870 - val_f1_score: 0.4498 - lr: 1.0000e-04
# Epoch 43/50
# 775/775 [==============================] - 269s 347ms/step - loss: 1.8450 - accuracy: 0.9002 - precision: 0.7083 - recall: 0.3433 - auc: 0.8923 - f1_score: 0.4601 - val_loss: 1.4098 - val_accuracy: 0.8988 - val_precision: 0.6879 - val_recall: 0.3485 - val_auc: 0.8858 - val_f1_score: 0.4599 - lr: 1.0000e-04
# Epoch 44/50
# 775/775 [==============================] - 271s 350ms/step - loss: 1.8405 - accuracy: 0.9004 - precision: 0.7095 - recall: 0.3435 - auc: 0.8920 - f1_score: 0.4607 - val_loss: 1.3976 - val_accuracy: 0.8991 - val_precision: 0.6914 - val_recall: 0.3488 - val_auc: 0.8874 - val_f1_score: 0.4611 - lr: 1.0000e-04
# Epoch 45/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.8408 - accuracy: 0.9009 - precision: 0.7109 - recall: 0.3497 - auc: 0.8918 - f1_score: 0.4666 - val_loss: 1.4310 - val_accuracy: 0.8975 - val_precision: 0.6701 - val_recall: 0.3550 - val_auc: 0.8813 - val_f1_score: 0.4609 - lr: 1.0000e-04
# Epoch 46/50
# 775/775 [==============================] - 270s 348ms/step - loss: 1.8300 - accuracy: 0.9012 - precision: 0.7127 - recall: 0.3508 - auc: 0.8930 - f1_score: 0.4679 - val_loss: 1.3984 - val_accuracy: 0.8987 - val_precision: 0.6773 - val_recall: 0.3616 - val_auc: 0.8864 - val_f1_score: 0.4696 - lr: 1.0000e-04
# Epoch 47/50
# 775/775 [==============================] - 270s 349ms/step - loss: 1.8233 - accuracy: 0.9013 - precision: 0.7113 - recall: 0.3534 - auc: 0.8937 - f1_score: 0.4698 - val_loss: 1.4101 - val_accuracy: 0.8977 - val_precision: 0.6784 - val_recall: 0.3454 - val_auc: 0.8832 - val_f1_score: 0.4549 - lr: 1.0000e-04
# Epoch 48/50
# 775/775 [==============================] - 268s 345ms/step - loss: 1.8161 - accuracy: 0.9022 - precision: 0.7184 - recall: 0.3572 - auc: 0.8940 - f1_score: 0.4746 - val_loss: 1.3985 - val_accuracy: 0.8988 - val_precision: 0.6825 - val_recall: 0.3558 - val_auc: 0.8854 - val_f1_score: 0.4649 - lr: 1.0000e-04
# Epoch 49/50
# 775/775 [==============================] - 267s 344ms/step - loss: 1.8175 - accuracy: 0.9005 - precision: 0.7054 - recall: 0.3502 - auc: 0.8935 - f1_score: 0.4657 - val_loss: 1.3868 - val_accuracy: 0.8991 - val_precision: 0.6916 - val_recall: 0.3480 - val_auc: 0.8870 - val_f1_score: 0.4597 - lr: 1.0000e-04
# Epoch 50/50
# 775/775 [==============================] - 266s 342ms/step - loss: 1.8024 - accuracy: 0.9017 - precision: 0.7158 - recall: 0.3549 - auc: 0.8954 - f1_score: 0.4724 - val_loss: 1.3894 - val_accuracy: 0.8990 - val_precision: 0.6897 - val_recall: 0.3485 - val_auc: 0.8861 - val_f1_score: 0.4600 - lr: 1.0000e-04

# %%
save_model = model.save('MobileNetV2_tf_224_grayscale.h5')

# %%
#Test the model
model = load_model('Model_Transfer/MOdel_transfer_96/MobileNetV2_tf.h5', compile=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 2
#       1 #Test the model
# ----> 2 model = load_model('Model_Transfer/MOdel_transfer_96/MobileNetV2_tf.h5', compile=False)
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\Users\darks\anaconda3\envs\Tensorflow2.9\lib\site-packages\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at Model_Transfer/MOdel_transfer_96/MobileNetV2_tf.h5

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 775/775 [==============================] - 473s 607ms/step - loss: 1.2100 - accuracy: 0.9097 - precision: 0.7556 - recall: 0.4106 - auc: 0.9176 - f1_score: 0.5286
# 194/194 [==============================] - 106s 547ms/step - loss: 1.3596 - accuracy: 0.9014 - precision: 0.6914 - recall: 0.3810 - auc: 0.8911 - f1_score: 0.4877

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>1.210</td>
#       <td>1.360</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.910</td>
#       <td>0.901</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.756</td>
#       <td>0.691</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.411</td>
#       <td>0.381</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.918</td>
#       <td>0.891</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.529</td>
#       <td>0.488</td>
#     </tr>
#   </tbody>
# </table>

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 194/194 [==============================] - 102s 509ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[ 65 107  61  59 137 129  67  96]
#  [ 68  75  46  69 111 115  69  82]
#  [ 46  74  52  50 107  84  58  61]
#  [ 84  91  47  82 129 148  63  80]
#  [ 99 116  80 105 185 189 100 135]
#  [124 141  78 105 174 200  98 106]
#  [ 65  96  63  59 131 112  75  85]
#  [102 120  59  77 134 169  87 111]]
# C:\Users\darks\AppData\Local\Temp\ipykernel_30732\3719412231.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()
# Out:
# C:\Users\darks\AppData\Local\Temp\ipykernel_30732\3749358223.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/sad/PrivateTest_10702106.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()

# %% [markdown]
# Test

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
